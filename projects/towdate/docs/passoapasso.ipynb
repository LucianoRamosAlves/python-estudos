# %% [markdown]
# Criar a pasta do projeto:

# %% [markdown]
# Criar o ambiente virtual:

# %%
python -m venv venv

# %%
# activate
venv\Scripts\activate

# %% [markdown]
# pip install Flask
#
# atualizar o pip
#
# python -m pip install --upgrade pip

# %% [markdown]
# intalei e trabalhei com rotas
#
# flask wtl
#
# token segurança
